# %% [markdown]
# <a href="https://colab.research.google.com/github/christophermalone/DSCI325/blob/main/Module6_Part1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 6 - Part 1 Python: Application Programming Interface (API) - Yelp

# %% [markdown]
# ## What is an API

# %% [markdown]
# An <strong>Application Programming Interface (API)</strong> is common method to obtain and share data across various applications.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1k7Y6z2RSr_91vhSduvYYqPB0h85AEooX"></p>
#
# Source:  https://en.wikipedia.org/wiki/API

# %% [markdown]
# An API allows for communication to easily transpire between a user and database (or server).

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=106-gH7Vj2VFPmFYRZeNYgKPQKZgl3cPD"></p>

# %% [markdown]
# <table width='100%' ><tr><td bgcolor='green'></td></tr></table>
#
# ## Example 6.1.P
# For this notebook, we will use the Yelp API to obtain data regarding the *Best Restaurants* in Winona, MN.
#
# The following search criteria will be used
#
# *   Locaton: Winona, MN
# *   Search Term: Best Restaurants
# *   Price: $, 1 dollar sign implies cheapest
# *   Sort by: Highest Rated
#
# Source:  https://www.yelp.com/search?find_desc=Best%20Restaurants&find_loc=Winona%2C%20MN%2055987&attrs=RestaurantsPriceRange2.1&sortby=rating
#
# <table width='100%' ><tr><td bgcolor='green'></td></tr></table>

# %% [markdown]
# ## Search via Yelp

# %% [markdown]
# Consider the following search done by Yelp.  The specifications of this search include: Search Term = "Best Restaurants", Location = "Winona, MN", 1 Filter applied for "$" (i.e. cheapest), and Sort outcomes by "Highest Rated".

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1gEpb125_jZfFg3hMvf3BWE2iut4tkpYd" width='100%' height='100%'></p>

# %% [markdown]
# The outcomes returned by Yelp are provided here.  Notice that the outcomes are *not* necessarily sorted by Highest Rating.  Bonnie Rae's Cafe is actually the highest rated is this list of three, but is not listed on top.  I would imagine that Yelp takes into consideration the number of reviews when determining "best".  For example, a restraurant with an overall rating of 5 based on two reviews should probably be rated lower than a restraurant with an overall rating of 4.5 based on several hundred reviews.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1k8j_BT3VBuY4tuFNQZDY6wAZIm7kPvSB" width='50%' height='50%'></p>

# %% [markdown]
# <strong>Goal</strong>:  To obtain a list that is truely sorted by Rating.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1viEjHStuLOVfnlptrUe9ZdRleMM0w7D7" width="50%" height="50%"></p>

# %% [markdown]
# ## Setting up an Account at Yelp

# %% [markdown]
# Most often, the first step in using an API is to create an account with the organization that owns the API.  For this Notebook we will be using the Yelp APO; thus, an developer account will need to be created at Yelp.
#
# Yelp Developer Site: https://www.yelp.com/developers

# %% [markdown]
# The next step is to fill out the required form for your new "app".  In this class, we will not be creating an actual app, but this form is required in order to obtain a:
#
# *    <strong>Client ID</strong>: Unique identifier for yourself
# *    <strong> API Key</strong>: Unique identifier for your app
#
# These two identifiers are somewhat common when working with APIs.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=14_kwYRq9yTLwtog0Rd8Gv06M_GaaxDWA" width='50%' height='50%'></p>

# %% [markdown]
# ## Setting up Python

# %% [markdown]
# First, install pandas and np packages for working with data in Python.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The <strong>YelpAPI</strong> package in Python requires the specificaiton of your Client ID and API Key.  Obtain the Client ID and API Key from the Yelp Developer site and copy and paste these strings here.

# %%
#Setting up API Connection Information
client_id = ""
api_key = ""

# %% [markdown]
# Next, download the YelpAPI package for Python. This will make connecting the the Yelp Fusion API *much* easier.
#
# Source:  https://github.com/gfairchild/yelpapi

# %%
pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yelpapi) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yelpapi) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yelpapi) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yelpapi) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yelpapi) (3.0.4)

# %% [markdown]
# Next, load the YelpAPI package into this Colab session.

# %%
from yelpapi import YelpAPI

# %% [markdown]
# Next, the <strong>YelpAPI()</strong> function establishes a connection with the Yelp Fusion API.  Additional details regarding this fuction can be found on the github site referenced above.

# %%
yelp_api = YelpAPI(api_key)

# %% [markdown]
# ## Making an API Call

# %% [markdown]
# A call to the API requires specification of a set of parameters.  Some of these parameters are required, e.g. location, and others are options, e.g. price.  The list of possible parameters can be found on the Yelp's documuntation page.
#
# Source: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1vJZV638yTbpJvLZOwF7imatucWLGNvmr" width='50%' height='50%'></p>

# %% [markdown]
# The following specifications will be used for our first API call.
#
#
# *   <strong>Term</strong>: Best Restaurants
# *   <strong>Location</strong>: Winona, MN
# *   <strong>Search Limit</strong>: Use 50 -- the maximum possible
#
#
# <strong>Comment</strong>:  If more than 50 outcomes are desired, the <strong>offset</strong> parameter can be used to obtain the *next* set of 50.

# %%
#Making a call to the Yelp Fusion API
term = 'Best Restaurants'
location = 'Winona, MN'
search_limit = 50  # 50 is the maximum for a single api call


response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)

# %% [markdown]
# ## The API Outcomes

# %% [markdown]
# Often, the <strong>JSON</strong> data format is used by APIs. A JSON data struture is much more flexible than a dataframe, e.g. JSON allows for *nested* data structures.  Most often a dataframe requires data to be in a tabluar format with clearly defined rows and columns.  A quick review of the information returned by the YelpAPI suggests that a dataframe is not the best way to store such informaiton.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1XR5qYZQnb4pC4tyFm8qI3uDD2mTfNc8y" width='75%' height='75%'></p>

# %% [markdown]
# The YelpAPI has *automatically* converted the JSON data structure into a Python dictionary - a commonly used data struture within Python that allows for more struture than a dataframe.

# %%
type(response)
# Out:
# dict

# %% [markdown]
# Taking a look at the contents of the response dictionary.

# %%
response
# Out:
# {'businesses': [{'alias': 'culvers-winona',
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 44.04708839393416,
#     'longitude': -91.67642196126742},
#    'display_phone': '(507) 457-9030',
#    'distance': 1439.097853692298,
#    'id': 'rhd0RNi4hAWs8v7lMoUi1g',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1oPG-fkCF5QI4znL-A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1441 Service Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['1441 Service Dr', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': "Culver's",
#    'phone': '+15074579030',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 12,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/culvers-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'witoka-tavern-winona',
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 43.9338, 'longitude': -91.61757},
#    'display_phone': '(507) 452-4346',
#    'distance': 13677.717017867075,
#    'id': 'ZDedy6V2pHQJEa7M-VBijQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QR0kwEHGMOrInKIpamqRMQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '27983 County Rd 9',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['27983 County Rd 9', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Witoka Tavern',
#    'phone': '+15074524346',
#    'rating': 1.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/witoka-tavern-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'winona-sandwich-company-winona',
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.04518, 'longitude': -91.64845},
#    'display_phone': '(507) 452-1170',
#    'distance': 1272.943495529727,
#    'id': 'nXLtko08rnGvaPiL0YkF7A',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgRkiOW5ZomQ1e9WzQA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '619 Huff St',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['619 Huff St', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Winona Sandwich Company',
#    'phone': '+15074521170',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 39,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/winona-sandwich-company-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'shawnees-bar-and-grill-rushford',
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.8083671621537,
#     'longitude': -91.7529528925154},
#    'display_phone': '(507) 864-2073',
#    'distance': 28181.064682070533,
#    'id': '4UAtEber_B-YF94vy4-0-A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/blA-DHx7VbhHZCcvkuQZGQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '220 S Mill St',
#     'address2': None,
#     'address3': None,
#     'city': 'Rushford',
#     'country': 'US',
#     'display_address': ['220 S Mill St', 'Rushford, MN 55971'],
#     'state': 'MN',
#     'zip_code': '55971'},
#    'name': "Shawnee's Bar and Grill",
#    'phone': '+15078642073',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/shawnees-bar-and-grill-rushford?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'pizza-corral-holmen',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 43.9514885, 'longitude': -91.2593536},
#    'display_phone': '(608) 526-3660',
#    'distance': 33980.46449613332,
#    'id': 'Ebw71T8tfu8GCi2wwFS7TQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ekGS6neasgg_gM-4j9MiAw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1505 S Holmen Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Holmen',
#     'country': 'US',
#     'display_address': ['1505 S Holmen Dr', 'Holmen, WI 54636'],
#     'state': 'WI',
#     'zip_code': '54636'},
#    'name': 'Pizza Corral',
#    'phone': '+16085263660',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 27,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/pizza-corral-holmen?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'jts-corner-bar-and-grill-houston',
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 43.7635002, 'longitude': -91.5676575},
#    'display_phone': '(507) 896-3232',
#    'distance': 33020.90697784959,
#    'id': 'RAhvgqFfC_GmdDOBeWRrug',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PHqOPHavKbGbin6p_hyh5w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '125 E Cedar St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'country': 'US',
#     'display_address': ['125 E Cedar St', 'Houston, MN 55943'],
#     'state': 'MN',
#     'zip_code': '55943'},
#    'name': "JT'S Corner Bar & Grill",
#    'phone': '+15078963232',
#    'price': '$',
#    'rating': 5.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jts-corner-bar-and-grill-houston?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'the-mexcal-la-crosse',
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'coordinates': {'latitude': 43.8126176077859,
#     'longitude': -91.25129780601962},
#    'display_phone': '(608) 519-0320',
#    'distance': 42265.57604167423,
#    'id': 'YGsB5vsWqfHGLd0x1o60mg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/v0_9nKJeDnCrwH-A1efMgg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '333 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['333 Main St', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'The Mexcal',
#    'phone': '+16085190320',
#    'rating': 3.5,
#    'review_count': 11,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/the-mexcal-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'kfc-winona-2',
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'coordinates': {'latitude': 44.0498713249133,
#     'longitude': -91.6788713122511},
#    'display_phone': '(507) 452-7719',
#    'distance': 1520.3763740041638,
#    'id': '5090HUm8Jq0QN3mfqr2VQw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IxxWAF54RSqC6OevCHg6vQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1558 Service Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['1558 Service Dr', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'KFC',
#    'phone': '+15074527719',
#    'price': '$',
#    'rating': 3.0,
#    'review_count': 5,
#    'transactions': ['pickup'],
#    'url': 'https://www.yelp.com/biz/kfc-winona-2?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'champions-riverside-resort-galesville',
#    'categories': [{'alias': 'campgrounds', 'title': 'Campgrounds'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 44.062534, 'longitude': -91.284172},
#    'display_phone': '(608) 582-2995',
#    'distance': 30059.30797696455,
#    'id': 'SYus9h4_eM8NdBI61N1wAQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TY-bOAiO01vJjjLDDcTIcg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'W16751 Pow Wow Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Galesville',
#     'country': 'US',
#     'display_address': ['W16751 Pow Wow Ln', 'Galesville, WI 54630'],
#     'state': 'WI',
#     'zip_code': '54630'},
#    'name': 'Champions Riverside Resort',
#    'phone': '+16085822995',
#    'price': '$$',
#    'rating': 2.5,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/champions-riverside-resort-galesville?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'meringue-bakery-and-cafe-la-crosse',
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'coordinates': {'latitude': 43.81284, 'longitude': -91.25187},
#    'display_phone': '(608) 519-2683',
#    'distance': 42217.622665673676,
#    'id': 'ruX8PK3aHDLGbU760AjOjA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xZwUiCWhCL7w0tFgsA3Yog/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '313 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['313 Main St', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'Meringue Bakery & Cafe',
#    'phone': '+16085192683',
#    'rating': 4.5,
#    'review_count': 12,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/meringue-bakery-and-cafe-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'little-ceasars-winona',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 44.0358, 'longitude': -91.61905},
#    'display_phone': '(507) 474-4679',
#    'distance': 3818.003542806685,
#    'id': 'SHa-Kp7C2yX3auZrCqWzWw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vQzK7eKqT4qtxmSJvWuAoQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '940 Frontenac Dr',
#     'address2': 'Ste 103',
#     'address3': None,
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['940 Frontenac Dr', 'Ste 103', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Little Ceasars',
#    'phone': '+15074744679',
#    'rating': 1.5,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/little-ceasars-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'the-crow-la-crosse',
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'coordinates': {'latitude': 43.812788, 'longitude': -91.252949},
#    'display_phone': '(608) 519-5400',
#    'distance': 42151.15882666717,
#    'id': 'h_H8TRq4Xi7QDmTLnEX8vw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MMOoJzme36dmwsuwn7533A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '100 3rd St S',
#     'address2': '',
#     'address3': '',
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['100 3rd St S', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'The Crow',
#    'phone': '+16085195400',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 183,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-crow-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'baristas-coffee-house-houston',
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 43.763871, 'longitude': -91.568615},
#    'display_phone': '(507) 896-5282',
#    'distance': 32963.58268480303,
#    'id': 'Wto8Gor5v0sK0krEIV3XGg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P-MzJ7rs8wLN8L8LgDnmEw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '110 N Grant St',
#     'address2': None,
#     'address3': None,
#     'city': 'Houston',
#     'country': 'US',
#     'display_address': ['110 N Grant St', 'Houston, MN 55943'],
#     'state': 'MN',
#     'zip_code': '55943'},
#    'name': "Barista's Coffee House",
#    'phone': '+15078965282',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 18,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/baristas-coffee-house-houston?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'riverview-lanes-arcadia',
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.25374, 'longitude': -91.50604},
#    'display_phone': '(608) 323-7005',
#    'distance': 25508.10396319108,
#    'id': '9_Ogzcn7Cz8Qk4oxF-8_oA',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '634 W Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Arcadia',
#     'country': 'US',
#     'display_address': ['634 W Main St', 'Arcadia, WI 54612'],
#     'state': 'WI',
#     'zip_code': '54612'},
#    'name': 'Riverview Lanes',
#    'phone': '+16083237005',
#    'rating': 1.0,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/riverview-lanes-arcadia?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'hungry-point-bar-and-grill-trempealeau',
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 43.9975224, 'longitude': -91.429427},
#    'display_phone': '(608) 534-7771',
#    'distance': 19584.471887394495,
#    'id': 'OO6dpszNBM066NjylxldDw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NLd4O2wuwFZf8vx2T_BR1Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '23797 Lake Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Trempealeau',
#     'country': 'US',
#     'display_address': ['23797 Lake Rd', 'Trempealeau, WI 54661'],
#     'state': 'WI',
#     'zip_code': '54661'},
#    'name': 'Hungry Point Bar & Grill',
#    'phone': '+16085347771',
#    'price': '$',
#    'rating': 3.0,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/hungry-point-bar-and-grill-trempealeau?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'stumpys-restaurant-and-bar-rushford',
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.8079681396484,
#     'longitude': -91.7543029785156},
#    'display_phone': '(507) 864-7156',
#    'distance': 28256.198271761572,
#    'id': 'IPqsDrUAjmCaeu0dUcXs4Q',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hqsp7GUn487V7QzZk2k2WQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '122 W Jessie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Rushford',
#     'country': 'US',
#     'display_address': ['122 W Jessie St', 'Rushford, MN 55971'],
#     'state': 'MN',
#     'zip_code': '55971'},
#    'name': "Stumpy's Restaurant & Bar",
#    'phone': '+15078647156',
#    'rating': 3.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/stumpys-restaurant-and-bar-rushford?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'pizza-factory-arcadia',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 44.2523040622473,
#     'longitude': -91.4987459778786},
#    'display_phone': '(608) 323-3636',
#    'distance': 25641.350652944173,
#    'id': 'LLQWokxwxnjMOlI3HHVEAA',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '116 E Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Arcadia',
#     'country': 'US',
#     'display_address': ['116 E Main St', 'Arcadia, WI 54612'],
#     'state': 'WI',
#     'zip_code': '54612'},
#    'name': 'Pizza Factory',
#    'phone': '+16083233636',
#    'rating': 4.5,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/pizza-factory-arcadia?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'great-hunan-restaurant-winona',
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'coordinates': {'latitude': 44.052788873526, 'longitude': -91.638455133419},
#    'display_phone': '(507) 452-1556',
#    'distance': 1746.4727356021315,
#    'id': 'hH74DcV0LgTfBSMs--5B6Q',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK38viyWe-JWgbECckg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '111 W 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['111 W 3rd St', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Great Hunan Restaurant',
#    'phone': '+15074521556',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 28,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/great-hunan-restaurant-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'town-and-country-cafe-kellogg',
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'coordinates': {'latitude': 44.30778, 'longitude': -91.99633},
#    'display_phone': '(507) 767-4593',
#    'distance': 39002.215798232784,
#    'id': 'VSNLNtdAwpv9TYH9zbqLBw',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '320 E Belvidere Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kellogg',
#     'country': 'US',
#     'display_address': ['320 E Belvidere Ave', 'Kellogg, MN 55945'],
#     'state': 'MN',
#     'zip_code': '55945'},
#    'name': 'Town & Country Cafe',
#    'phone': '+15077674593',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/town-and-country-cafe-kellogg?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'perkins-restaurant-and-bakery-winona',
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'coordinates': {'latitude': 44.0301764, 'longitude': -91.6210466623306},
#    'display_phone': '(507) 452-1618',
#    'distance': 4026.6491411484553,
#    'id': '6tvqP50bsIf9nDtKOoBLeQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ps6qEBJ2-NIb7kESM7OiRQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '956 1 /2 Mankoto Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['956 1 /2 Mankoto Ave', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Perkins Restaurant & Bakery',
#    'phone': '+15074521618',
#    'price': '$$',
#    'rating': 2.5,
#    'review_count': 21,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/perkins-restaurant-and-bakery-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'four-corners-trempealeau',
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 44.06975964101293,
#     'longitude': -91.45140359999999},
#    'display_phone': '(608) 534-2111',
#    'distance': 16797.75773051755,
#    'id': 'YqEmkF5utch2yZPYK5tkEA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LW7IaUPvDI7vDxR59TbR8w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'W25013 WI-54 35',
#     'address2': None,
#     'address3': '',
#     'city': 'Trempealeau',
#     'country': 'US',
#     'display_address': ['W25013 WI-54 35', 'Trempealeau, WI 54661'],
#     'state': 'WI',
#     'zip_code': '54661'},
#    'name': 'Four Corners',
#    'phone': '+16085342111',
#    'rating': 1.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/four-corners-trempealeau?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'soulas-cuisina-la-crosse',
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'coordinates': {'latitude': 43.81201, 'longitude': -91.25077},
#    'display_phone': '(608) 881-6888',
#    'distance': 42340.07494514722,
#    'id': 'EJvF8HG4U7cTo7_tjgNbvQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XbHbSSQDI_PIlwwZTRhZhg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '412 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['412 Main St', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': "Soula's Cuisina",
#    'phone': '+16088816888',
#    'rating': 4.0,
#    'review_count': 4,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/soulas-cuisina-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'sub-zero-pizza-and-ice-cream-houston',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 43.7629737854004,
#     'longitude': -91.5665588378906},
#    'display_phone': '(507) 896-2452',
#    'distance': 33096.48255293616,
#    'id': 'uqqtfN_T4YIs6kqb3ww5RQ',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '210 E Cedar St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'country': 'US',
#     'display_address': ['210 E Cedar St', 'Houston, MN 55943'],
#     'state': 'MN',
#     'zip_code': '55943'},
#    'name': 'Sub-Zero Pizza & Ice Cream',
#    'phone': '+15078962452',
#    'price': '$$',
#    'rating': 5.0,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/sub-zero-pizza-and-ice-cream-houston?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'burdeys-cafe-peterson',
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 43.7861400242264,
#     'longitude': -91.8340901657939},
#    'display_phone': '(507) 875-2424',
#    'distance': 32762.27565509446,
#    'id': 'ojz-aKGOoAkSeJ4C34kb4Q',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N6t2Xjbj1FN5qKHDRw5uxg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '417 Mill St',
#     'address2': '',
#     'address3': None,
#     'city': 'Peterson',
#     'country': 'US',
#     'display_address': ['417 Mill St', 'Peterson, MN 55962'],
#     'state': 'MN',
#     'zip_code': '55962'},
#    'name': "Burdey's Cafe",
#    'phone': '+15078752424',
#    'rating': 4.5,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/burdeys-cafe-peterson?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'quillins-la-crescent',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 43.82885, 'longitude': -91.30418},
#    'display_phone': '(507) 895-2245',
#    'distance': 37835.451905481874,
#    'id': 'Pej_K261UAGbwZrRJaJFiQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gP27DBKbOd5ucvkPK6X_pw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '24 S Walnut St',
#     'address2': '',
#     'address3': None,
#     'city': 'La Crescent',
#     'country': 'US',
#     'display_address': ['24 S Walnut St', 'La Crescent, MN 55947'],
#     'state': 'MN',
#     'zip_code': '55947'},
#    'name': "Quillin's",
#    'phone': '+15078952245',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/quillins-la-crescent?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'subway-lewiston-18',
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 43.9884514569234,
#     'longitude': -91.8606164711961},
#    'display_phone': '(507) 523-3500',
#    'distance': 17544.990191595214,
#    'id': 'JtC1GEkQxTq4hg2nwysbfw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7oEUIEaSaUzDjPeoG0YDTw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '560 B Debra Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Lewiston',
#     'country': 'US',
#     'display_address': ['560 B Debra Dr', 'Lewiston, MN 55952'],
#     'state': 'MN',
#     'zip_code': '55952'},
#    'name': 'Subway',
#    'phone': '+15075233500',
#    'price': '$',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/subway-lewiston-18?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'apothik-eatery-food-truck-la-crosse',
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 43.8127656961605, 'longitude': -91.2525493},
#    'display_phone': '(608) 298-3850',
#    'distance': 42177.50778546529,
#    'id': '86Djp7jaANv5mNGvQnPwbQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s-rnPyRXQVhiwyBnfYbgxw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '411 3rd St S',
#     'address2': '',
#     'address3': '',
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['411 3rd St S', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'Apothik Eatery + Food Truck',
#    'phone': '+16082983850',
#    'rating': 4.0,
#    'review_count': 16,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/apothik-eatery-food-truck-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'arbys-winona',
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.027531, 'longitude': -91.618019},
#    'display_phone': '(507) 262-3803',
#    'distance': 4397.830922033792,
#    'id': 'bu2pQPFcxVhF4I8mizPVzQ',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '1055 HWY 61 EAST',
#     'address2': None,
#     'address3': None,
#     'city': 'WINONA',
#     'country': 'US',
#     'display_address': ['1055 HWY 61 EAST', 'WINONA, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': "Arby's",
#    'phone': '+15072623803',
#    'rating': 2.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/arbys-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'subway-winona-11',
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.0489610060988,
#     'longitude': -91.6772112482967},
#    'display_phone': '(507) 454-8338',
#    'distance': 1418.8759587906902,
#    'id': 'k1FO3_aHPQLns-PA78vmqw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gOa3iqIaSNbJGjuDNj6v4Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1488 Gilmore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['1488 Gilmore Ave', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Subway',
#    'phone': '+15074548338',
#    'price': '$',
#    'rating': 3.0,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/subway-winona-11?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'the-driftless-axe-la-crosse',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'coordinates': {'latitude': 43.81084, 'longitude': -91.25214},
#    'display_phone': '(608) 571-7246',
#    'distance': 42342.042562697716,
#    'id': 'h9Mv4uTENDlEyuIdCp2d0g',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '300 4th St S',
#     'address2': 'Ste 101',
#     'address3': None,
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['300 4th St S', 'Ste 101', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'The Driftless Axe',
#    'phone': '+16085717246',
#    'rating': 4.5,
#    'review_count': 3,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/the-driftless-axe-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'hardees-saint-charles-7',
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 43.954264, 'longitude': -92.064551},
#    'display_phone': '(507) 932-9972',
#    'distance': 33833.46515189597,
#    'id': 'lxlEdthrqnSLaXf39lwCeg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-ftN-RSYlZ24hJUmZKxNqg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2102 Enterprise Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'St. Charles',
#     'country': 'US',
#     'display_address': ['2102 Enterprise Dr', 'St. Charles, MN 55972'],
#     'state': 'MN',
#     'zip_code': '55972'},
#    'name': "Hardee's",
#    'phone': '+15079329972',
#    'rating': 2.5,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/hardees-saint-charles-7?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'kaddys-kafe-la-crescent',
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'coordinates': {'latitude': 43.8293444716639,
#     'longitude': -91.3036136102516},
#    'display_phone': '(507) 895-2900',
#    'distance': 37859.823009701904,
#    'id': 'B4RNwTJgvU-CyNHfZmqvxQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cJXl6rc29k2HMS4TMqN_KA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '236 E Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'La Crescent',
#     'country': 'US',
#     'display_address': ['236 E Main St', 'La Crescent, MN 55947'],
#     'state': 'MN',
#     'zip_code': '55947'},
#    'name': "Kaddy's Kafe",
#    'phone': '+15078952900',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 28,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/kaddys-kafe-la-crescent?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'sammys-pizza-winona',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 44.05424, 'longitude': -91.63828},
#    'display_phone': '(507) 474-7400',
#    'distance': 1762.5196062552197,
#    'id': 'RqWJBMBvUoaLCZcTKU_FQQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gcD87fppFuyOgTVj1j3myw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '126 W 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['126 W 2nd St', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': "Sammy's Pizza",
#    'phone': '+15074747400',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 39,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/sammys-pizza-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'dominos-pizza-winona',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.0401280376907,
#     'longitude': -91.6766166137695},
#    'display_phone': '(507) 454-4545',
#    'distance': 1924.8167046168476,
#    'id': 'Sd5BCBH_-YdsZrsY5ZO3qQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cakz-JtBuGbQ1JgvBGhuPg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1201 Gilmore Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['1201 Gilmore Ave', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': "Domino's Pizza",
#    'phone': '+15074544545',
#    'price': '$',
#    'rating': 2.5,
#    'review_count': 8,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/dominos-pizza-winona?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'liberty-peak-deli-trempealeau',
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 44.0051483, 'longitude': -91.4425655},
#    'display_phone': '(608) 534-5504',
#    'distance': 18199.108694637926,
#    'id': 'Mx8hB5m75QTQ-QMTFkSUMw',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '11367 Main St',
#     'address2': None,
#     'address3': None,
#     'city': 'Trempealeau',
#     'country': 'US',
#     'display_address': ['11367 Main St', 'Trempealeau, WI 54661'],
#     'state': 'WI',
#     'zip_code': '54661'},
#    'name': 'Liberty Peak Deli',
#    'phone': '+16085345504',
#    'rating': 3.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/liberty-peak-deli-trempealeau?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'midway-deli-onalaska',
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 43.9234695, 'longitude': -91.2514725},
#    'display_phone': '(608) 783-3540',
#    'distance': 35733.197413320966,
#    'id': 'DsVpvrcXuZHZ_bGaCrVLEQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ueT-EP9kYX1QWSfNmg2obg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'N5610 County Rd Ot',
#     'address2': '',
#     'address3': '',
#     'city': 'Onalaska',
#     'country': 'US',
#     'display_address': ['N5610 County Rd Ot', 'Onalaska, WI 54650'],
#     'state': 'WI',
#     'zip_code': '54650'},
#    'name': 'Midway Deli',
#    'phone': '+16087833540',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 13,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/midway-deli-onalaska?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'taste-of-thai-holmen-2',
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'coordinates': {'latitude': 43.96054, 'longitude': -91.26146},
#    'display_phone': '(608) 399-1585',
#    'distance': 33519.66380861972,
#    'id': 'vemb6MuK0yKRB701-41q0g',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IpG7khPKnQnr_7w7n7S8lQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '205 S Holmen Dr',
#     'address2': 'Ste 106',
#     'address3': None,
#     'city': 'Holmen',
#     'country': 'US',
#     'display_address': ['205 S Holmen Dr', 'Ste 106', 'Holmen, WI 54636'],
#     'state': 'WI',
#     'zip_code': '54636'},
#    'name': 'Taste of Thai',
#    'phone': '+16083991585',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 42,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/taste-of-thai-holmen-2?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'cozy-coffee-holmen-2',
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 43.967522583165,
#     'longitude': -91.2644755057601},
#    'display_phone': '(608) 399-3042',
#    'distance': 33047.77998793711,
#    'id': 'QBnovSkqDvcDnUo42sktgA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pyuFAdEKkcFcpP_zrhAwKw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '515 Amy Dr',
#     'address2': 'Ste 1',
#     'address3': None,
#     'city': 'Holmen',
#     'country': 'US',
#     'display_address': ['515 Amy Dr', 'Ste 1', 'Holmen, WI 54636'],
#     'state': 'WI',
#     'zip_code': '54636'},
#    'name': 'Cozy Coffee',
#    'phone': '+16083993042',
#    'rating': 4.5,
#    'review_count': 5,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/cozy-coffee-holmen-2?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'pizza-hut-holmen',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'coordinates': {'latitude': 43.952692, 'longitude': -91.256143},
#    'display_phone': '(608) 433-9558',
#    'distance': 34191.642133099645,
#    'id': 'tRt85W4dVE1QIycFHyT9sA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z9IFscqeMNCvSJLPKl-uJQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '129 Hale Dr',
#     'address2': None,
#     'address3': None,
#     'city': 'Holmen',
#     'country': 'US',
#     'display_address': ['129 Hale Dr', 'Holmen, WI 54636'],
#     'state': 'WI',
#     'zip_code': '54636'},
#    'name': 'Pizza Hut',
#    'phone': '+16084339558',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/pizza-hut-holmen?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'subway-winona-12',
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.0314382734419,
#     'longitude': -91.6218700336887},
#    'display_phone': '(507) 454-0534',
#    'distance': 3888.0123036728687,
#    'id': 'bukVjwhmHW19a2lGp7qecA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v0h6VnyG4XdZqKcq-z8k1A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '920 Mankato Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['920 Mankato Ave', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Subway',
#    'phone': '+15074540534',
#    'price': '$',
#    'rating': 1.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/subway-winona-12?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'the-twisted-moose-la-crosse',
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'coordinates': {'latitude': 43.8120966, 'longitude': -91.2532538},
#    'display_phone': '(608) 519-5217',
#    'distance': 42181.17299592738,
#    'id': '3TC-uakdWOWYnpgdGeqz-w',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kaj1zIihIRbfAdsGD8TQYw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '128 3rd St S',
#     'address2': None,
#     'address3': '',
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['128 3rd St S', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'La Crosse Bierhaus',
#    'phone': '+16085195217',
#    'price': '$$',
#    'rating': 2.5,
#    'review_count': 51,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/the-twisted-moose-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'rubios-family-mexican-restaurant-winona-2',
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'coordinates': {'latitude': 44.0436706542969,
#     'longitude': -91.6454544067383},
#    'display_phone': '(507) 474-4971',
#    'distance': 1568.9730382926393,
#    'id': '0Zi7qalSG8XcYkPU2sWc3w',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pNXsXhX6qenE41tzBry3Sw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '652 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['652 Washington St', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': "Rubio's Family Mexican Restaurant",
#    'phone': '+15074744971',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/rubios-family-mexican-restaurant-winona-2?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'dairy-queen-winona-3',
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'coordinates': {'latitude': 44.03072, 'longitude': -91.62311},
#    'display_phone': '(507) 454-0310',
#    'distance': 3875.459012890066,
#    'id': '9PjYNNHIE1ax6G0m9VS57Q',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SEGtLr0ftaSTNPxiwFa-dQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '965 Mankato Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Winona',
#     'country': 'US',
#     'display_address': ['965 Mankato Ave', 'Winona, MN 55987'],
#     'state': 'MN',
#     'zip_code': '55987'},
#    'name': 'Dairy Queen',
#    'phone': '+15074540310',
#    'price': '$',
#    'rating': 1.0,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/dairy-queen-winona-3?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'mcdonalds-arcadia-8',
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'coordinates': {'latitude': 44.2495439445674,
#     'longitude': -91.4725755423279},
#    'display_phone': '(608) 323-3153',
#    'distance': 26506.880396480774,
#    'id': 'bDE8tplYzvaHnilLbHQWZQ',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '310 Nelson Dr',
#     'address2': None,
#     'address3': None,
#     'city': 'Arcadia',
#     'country': 'US',
#     'display_address': ['310 Nelson Dr', 'Arcadia, WI 54612'],
#     'state': 'WI',
#     'zip_code': '54612'},
#    'name': "McDonald's",
#    'phone': '+16083233153',
#    'price': '$',
#    'rating': 2.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/mcdonalds-arcadia-8?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'boondocks-locker-room-galesville',
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 44.04884, 'longitude': -91.371624},
#    'display_phone': '(608) 582-4401',
#    'distance': 23075.520393905732,
#    'id': 'An__SpS_gTN41XM_ybn9Ig',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JyWIIDZqvEDnfjvgolMC9Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'N14433 CR-M',
#     'address2': None,
#     'address3': None,
#     'city': 'Galesville',
#     'country': 'US',
#     'display_address': ['N14433 CR-M', 'Galesville, WI 54630'],
#     'state': 'WI',
#     'zip_code': '54630'},
#    'name': 'Boondocks Locker Room',
#    'phone': '+16085824401',
#    'rating': 3.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/boondocks-locker-room-galesville?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'swing-bridge-pub-la-crescent',
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'coordinates': {'latitude': 43.827980041503906,
#     'longitude': -91.3437728881836},
#    'display_phone': '(507) 895-1110',
#    'distance': 37598.68404619579,
#    'id': 'BSlwQOvH60SarG_l-Fpb6Q',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '595 Veterans Pkwy',
#     'address2': 'Ste 200',
#     'address3': '',
#     'city': 'La Crescent',
#     'country': 'US',
#     'display_address': ['595 Veterans Pkwy',
#      'Ste 200',
#      'La Crescent, MN 55947'],
#     'state': 'MN',
#     'zip_code': '55947'},
#    'name': 'Swing Bridge Pub',
#    'phone': '+15078951110',
#    'rating': 3.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/swing-bridge-pub-la-crescent?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'pioneer-club-wabasha',
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 44.3281326293945,
#     'longitude': -91.9495162963867},
#    'display_phone': '(651) 565-3309',
#    'distance': 38337.87503845977,
#    'id': 'x28C6KoVIs_CnNWIXNP7NQ',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '14026 657th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Wabasha',
#     'country': 'US',
#     'display_address': ['14026 657th St', 'Wabasha, MN 55981'],
#     'state': 'MN',
#     'zip_code': '55981'},
#    'name': 'Pioneer Club',
#    'phone': '+16515653309',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/pioneer-club-wabasha?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'angrys-way-out-brice-prairie',
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'coordinates': {'latitude': 43.934299, 'longitude': -91.299961},
#    'display_phone': '(608) 615-1115',
#    'distance': 31698.040560538997,
#    'id': 'fHRO-drJuUH8J_NuE771-A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f_kzjtP9cFw1WN29KTqsSA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'N5914 County Rd Zz',
#     'address2': '',
#     'address3': None,
#     'city': 'Brice Prairie',
#     'country': 'US',
#     'display_address': ['N5914 County Rd Zz', 'Brice Prairie, WI 54650'],
#     'state': 'WI',
#     'zip_code': '54650'},
#    'name': "Angry's Way Out",
#    'phone': '+16086151115',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/angrys-way-out-brice-prairie?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'burger-king-holmen',
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'coordinates': {'latitude': 43.95021251015032,
#     'longitude': -91.26005883329873},
#    'display_phone': '(608) 526-2510',
#    'distance': 33987.91181982129,
#    'id': '61vPxOnymAPEB1u-u-2cqQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GEu-r37LELttoSrhdTdqtQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1540 S Holmen Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Holmen',
#     'country': 'US',
#     'display_address': ['1540 S Holmen Dr', 'Holmen, WI 54636'],
#     'state': 'WI',
#     'zip_code': '54636'},
#    'name': 'Burger King',
#    'phone': '+16085262510',
#    'price': '$',
#    'rating': 1.0,
#    'review_count': 1,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/burger-king-holmen?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'},
#   {'alias': 'three-rivers-lodge-river-view-restaurant-and-bar-la-crosse',
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 43.813191, 'longitude': -91.255055},
#    'display_phone': '(608) 793-5018',
#    'distance': 41992.24621197214,
#    'id': 'QYBTQiSoBGPPq37WiyiW9Q',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j30xA0uR0FspTRGXanSgLA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '111 Front St S',
#     'address2': None,
#     'address3': '',
#     'city': 'La Crosse',
#     'country': 'US',
#     'display_address': ['111 Front St S', 'La Crosse, WI 54601'],
#     'state': 'WI',
#     'zip_code': '54601'},
#    'name': 'Three Rivers Lodge River View Restaurant and Bar',
#    'phone': '+16087935018',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 32,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/three-rivers-lodge-river-view-restaurant-and-bar-la-crosse?adjust_creative=Lb5N_d2GlF2uqp7cMBNlBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lb5N_d2GlF2uqp7cMBNlBg'}],
#  'region': {'center': {'latitude': 44.052865783279955,
#    'longitude': -91.66030883789062}},
#  'total': 211}

# %% [markdown]
# **Problem**:  The data pulled from the Yelp API appears to be incomplete.  In particular, one of the top rated restaurants, i.e. Beno's Deli, is missing and was not retrieved in this first set of 50 restaurant that were retrieved from the Yelp Fusion API.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1lwvoZDdYpuYYxWIyWgH_DXnOIKYba3TQ" width='50%' height='50%'></p>

# %% [markdown]
# ## Using Offset parameter

# %% [markdown]
# The **offset** parameter for the Yelp Fusion API will be used to obtain more restuarants beyond the search limit.  Currently, the maximum number of restaurants that can be pulled from a single API call is 50. The Offset argument in the **yelp_api.search_query() ** will tell the Yelp Fusion API to retrieve a second set of restaurants.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=10MNgr3aOrrjNuqd_X8QyWMV72k6n3YvY" width='50%' height='50%'></p>

# %% [markdown]
# Consider the following code that retrieves 3 sets of 50 restaurants from the Yelp Fusion API.

# %%
term = 'Best Restaurants'
location = 'Winona, MN'
search_limit = 50  # 50 is the maximum for a single api call

#Calling Yelp API for Set #1
response_set1 = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit,
                                 offset=0)

#Calling Yelp API for Set #2, Offset=50
response_set2 = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit,
                                 offset=50)

#Calling Yelp API for Set #3, Offset=100
response_set3 = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit,
                                 offset=100)

# %% [markdown]
# ## Putting data into a single data.frame

# %% [markdown]
# The next data processing step will be to put the outcomes from each set into a single data.frame.  A custom function called convert_dict_to_df() will be used for this task.

# %% [markdown]
# <table width='100%'><tr><td bgcolor='orange' align='center'><font size="+2">Python Function</font></td></tr></table>

# %%
def convert_dict_to_df(mydictionary):
  '''  Purpose: This function is used to convert a dictionay returned from the Yelp Fusion API into a data.frame 

       Args:
         mydictionary: a dictionary that is returned by the yelp_api.search_query() function
                 
      Returns: the converted data.frame 
  '''
  
  cols = list(mydictionary['businesses'][0].keys())
  local_df = pd.DataFrame(columns=cols)

  for biz in mydictionary['businesses']:
    local_df = local_df.append(biz, ignore_index=True)


  return(local_df)

# %% [markdown]
# <table width='100%'><tr><td bgcolor='orange' align='center'><font size="+2">&nbsp;</font></td></tr></table>

# %% [markdown]
# Next, use the custom convert_dict_to_df() function to convert each dictionary to a data.frame.

# %%
#Using the convert_dict_to_df() function for each set
WinonaYelp_Set1 = convert_dict_to_df(response_set1)
WinonaYelp_Set2 = convert_dict_to_df(response_set2)
WinonaYelp_Set3 = convert_dict_to_df(response_set3)

# %% [markdown]
# Checking the data type and size of the the data.frame returned by the convert_dict_to_df() function.

# %%
print(type(WinonaYelp_Set1))
print(WinonaYelp_Set1.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (50, 16)

# %% [markdown]
# Next, using pd.concat() function to concatenate / append the three data.frames.

# %%
WinonaYelp = pd.concat([WinonaYelp_Set1, WinonaYelp_Set2, WinonaYelp_Set3])

# %% [markdown]
# Making sure the three data.frames were correctly appended.

# %%
WinonaYelp.shape
# Out:
# (150, 16)

# %% [markdown]
# Using the head() method to look at the first three records in the WinonaYelp data.frame.

# %%
WinonaYelp.head(3)
# Out:
#                        id                            alias  \
# 0  G2ptcgOx5e9usmxW38OoOw  hillside-fish-house-marshland-2
# 1  b7AuH8sAf0IDs6ZR8sPAtg            the-boat-house-winona
# 2  w_G_5c6IxJ98-3WT01XLnw   signatures-restaurant-winona-3
#
#                     name                                          image_url  \
# 0    Hillside Fish House  https://s3-media3.fl.yelpcdn.com/bphoto/IBZ-vV...
# 1         The Boat House  https://s3-media2.fl.yelpcdn.com/bphoto/sx-wDQ...
# 2  Signatures Restaurant  https://s3-media2.fl.yelpcdn.com/bphoto/ryaRwx...
#
#   is_closed                                                url review_count  \
# 0     False  https://www.yelp.com/biz/hillside-fish-house-m...           39
# 1     False  https://www.yelp.com/biz/the-boat-house-winona...           92
# 2     False  https://www.yelp.com/biz/signatures-restaurant...           36
#
#                                           categories  rating  \
# 0  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.0
# 1  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 2  [{'alias': 'newamerican', 'title': 'American (...     3.5
#
#                                          coordinates transactions price  \
# 0     {'latitude': 44.07125, 'longitude': -91.55721}           []    $$
# 1  {'latitude': 44.0550145, 'longitude': -91.6381...           []    $$
# 2  {'latitude': 44.007709875787, 'longitude': -91...           []   $$$
#
#                                             location         phone  \
# 0  {'address1': 'W124 State Rd 35 54', 'address2'...  +16086876141
# 1  {'address1': '2 Johnson St', 'address2': '', '...  +15074746550
# 2  {'address1': '22852 County Rd 17', 'address2':...  +15074543767
#
#     display_phone     distance
# 0  (608) 687-6141  8487.767680
# 1  (507) 474-6550  1786.461266
# 2  (507) 454-3767  6653.677548

# %% [markdown]
# <strong>Note</strong>:  Not all of the contents will be converted into seperate fields. For example, the contents of the categories, coordinates, and location fields have not yet be exploded into seperate columns.

# %% [markdown]
# <table width='100%' ><tr><td bgcolor='orange' align='center'><font size="+2">Aside: Google Sheet Style Output in Colab</font></td></tr></table>
#
# The following extension can be used to preview data via a Google Sheet structure inside of Colab.

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# The following command can be used to unload this extension from this session of Colab.

# %%
# %unload_ext google.colab.data_table

# %% [markdown]
# <table width='100%' ><tr><td bgcolor='orange'><font size="+2">&nbsp;</font></td></tr></table>

# %% [markdown]
# Looking at *all* rows in a window that acts more like a Google Sheet that includes Filter options, etc.

# %%
WinonaYelp

# %% [markdown]
# ## Using dfply package for cleaning the data.frame

# %%
pip install dfply
# Out:
# Collecting dfply
#   Downloading dfply-0.3.3-py3-none-any.whl (612 kB)
#      |████████████████████████████████| 612 kB 5.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from dfply) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dfply) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->dfply) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->dfply) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->dfply) (1.15.0)
# Installing collected packages: dfply
# Successfully installed dfply-0.3.3

# %%
from dfply import *

# %% [markdown]
# The following actions will take place on this dataframe.
#
#
# *   filter: filter on price == $, i.e. only keep cheapest restaurants
# *   arrange: sort the list by rating, and also by the number of reviews
# *   filter: only keep restaurants that have 10 or more reviews
# *   select: select a subset of fields

# %%
WinonaList = (
                 WinonaYelp
                 >> filter_by(X.price == '$')
                 >> arrange(desc(X.rating), desc(X.review_count))
                 >> filter_by(X.review_count >= 10)
                 >> select(X.name, X.image_url, X.review_count, X.rating, X.location)
             )

#Checking the dataframe
WinonaList
# Out:
#                              name  \
# 30           NorthEnd Pub & Grill
# 31                  The Root Note
# 47  Pickerman's Soup & Sandwiches
# 36                  Taste of Thai
# 27       River Rats Bar and Grill
# 31                   Kaddy's Kafe
# 19               Garden of Eatin'
# 15                    Beno's Deli
# 16         Brewskie's Bar & Grill
# 12         Barista's Coffee House
# 9                      River Cafe
# 35                    Midway Deli
# 22      Schmitty's TimeOut Tavern
# 13              The Acoustic Cafe
# 5              Lakeview Drive Inn
# 4                    Pizza Corral
# 44                    Pier 4 Cafe
# 16             Golden Frog Saloon
# 8      Creamery Pizza & Ice Cream
# 12            Rocco's Pub & Pizza
# 22                  Bub's Brewing
# 2         Winona Sandwich Company
# 17         Great Hunan Restaurant
# 30         Wingdam Saloon & Grill
# 0                        Culver's
# 35       Winona Family Restaurant
# 20       Wellington's Pub & Grill
# 10        The Grill at Signatures
#
#                                             image_url review_count  rating  \
# 30  https://s3-media4.fl.yelpcdn.com/bphoto/x5jzKR...           14     5.0
# 31  https://s3-media2.fl.yelpcdn.com/bphoto/ahQdtU...           82     4.5
# 47  https://s3-media4.fl.yelpcdn.com/bphoto/lfQw31...           64     4.5
# 36  https://s3-media4.fl.yelpcdn.com/bphoto/IpG7kh...           42     4.5
# 27  https://s3-media1.fl.yelpcdn.com/bphoto/FfTc_M...           35     4.5
# 31  https://s3-media3.fl.yelpcdn.com/bphoto/cJXl6r...           28     4.5
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/rW68Cp...           24     4.5
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC...           22     4.5
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/llnczw...           21     4.5
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/P-MzJ7...           18     4.5
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/8m2yDp...           17     4.5
# 35  https://s3-media1.fl.yelpcdn.com/bphoto/ueT-EP...           13     4.5
# 22  https://s3-media3.fl.yelpcdn.com/bphoto/btkUYa...           10     4.5
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/bcDdRg...           77     4.0
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/uDUhkd...           45     4.0
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/ekGS6n...           27     4.0
# 44  https://s3-media3.fl.yelpcdn.com/bphoto/w_h-vM...           26     4.0
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/IjH6sA...           25     4.0
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/4btuow...           14     4.0
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/pjaUxD...           12     4.0
# 22  https://s3-media1.fl.yelpcdn.com/bphoto/znNYZv...           66     3.5
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgR...           39     3.5
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK3...           28     3.5
# 30  https://s3-media1.fl.yelpcdn.com/bphoto/60SgiE...           15     3.5
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1o...           12     3.5
# 35  https://s3-media4.fl.yelpcdn.com/bphoto/lxYd9Z...           32     3.0
# 20  https://s3-media3.fl.yelpcdn.com/bphoto/_Ep3L8...           20     3.0
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/sBuQQs...           15     3.0
#
#                                              location
# 30  {'address1': '214 N Main St', 'address2': '', ...
# 31  {'address1': '115 4th St S', 'address2': '', '...
# 47  {'address1': '327 Jay St', 'address2': '', 'ad...
# 36  {'address1': '205 S Holmen Dr', 'address2': 'S...
# 27  {'address1': '1311 La Crescent Pl', 'address2'...
# 31  {'address1': '236 E Main St', 'address2': '', ...
# 19  {'address1': '19847 E Gale Ave', 'address2': '...
# 15  {'address1': '78 E 4th St', 'address2': '', 'a...
# 16  {'address1': '110 E Main St', 'address2': '', ...
# 12  {'address1': '110 N Grant St', 'address2': Non...
# 9   {'address1': '23991 3rd St', 'address2': None,...
# 35  {'address1': 'N5610 County Rd Ot', 'address2':...
# 22  {'address1': '444 N Chestnut St', 'address2': ...
# 13  {'address1': '77 Lafayette', 'address2': '', '...
# 5   {'address1': '610 E Sarnia St', 'address2': ''...
# 4   {'address1': '1505 S Holmen Dr', 'address2': '...
# 44  {'address1': '600 N Main St', 'address2': '', ...
# 16  {'address1': '112 N Shore Dr', 'address2': '',...
# 8   {'address1': '407 S Mill St', 'address2': '', ...
# 12  {'address1': '5242 W 6th St', 'address2': '', ...
# 22  {'address1': '65 E 4th St', 'address2': '', 'a...
# 2   {'address1': '619 Huff St', 'address2': '', 'a...
# 17  {'address1': '111 W 3rd St', 'address2': '', '...
# 30  {'address1': '1 N Shore Dr', 'address2': None,...
# 0   {'address1': '1441 Service Dr', 'address2': ''...
# 35  {'address1': '1611 Service Dr', 'address2': ''...
# 20  {'address1': '1429 W Service Dr', 'address2': ...
# 10  {'address1': '22852 County Road 17', 'address2...

# %% [markdown]
# The existing dataframe needs to be modified to include only locations in <strong>Winona, MN</strong>.  Furthermore, the display_address field will be used to create an connection with the Google Map API.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1Tk9TYbPYU7bIUcLUiX0LdrrW-X2U16OG" width='75%' height='75%'></p>

# %% [markdown]
# The following json_normalize() function is used to seperate the location field into seperate columns.

# %%
WinonaList_NormalizeLocation = pd.json_normalize(WinonaList['location'])

# %% [markdown]
# <strong>Note</strong>:  The following snipit of code to accomplish that same -- pd.DataFrame(WinonaList['location'].tolist())

# %%
WinonaList_NormalizeLocation
# Out:
#                 address1 address2 address3           city zip_code country  \
# 0          214 N Main St                         Cochrane    54622      US
# 1           115 4th St S                        La Crosse    54601      US
# 2             327 Jay St                        La Crosse    54601      US
# 3        205 S Holmen Dr  Ste 106     None         Holmen    54636      US
# 4    1311 La Crescent Pl     None           French Island    54603      US
# 5          236 E Main St              None    La Crescent    55947      US
# 6       19847 E Gale Ave                       Galesville    54630      US
# 7            78 E 4th St                           Winona    55987      US
# 8          110 E Main St                            Utica    55979      US
# 9         110 N Grant St     None     None        Houston    55943      US
# 10          23991 3rd St     None             Trempealeau    54661      US
# 11    N5610 County Rd Ot                         Onalaska    54650      US
# 12     444 N Chestnut St                      La Crescent    55947      US
# 13          77 Lafayette                           Winona    55987      US
# 14       610 E Sarnia St                           Winona    55987      US
# 15      1505 S Holmen Dr                           Holmen    54636      US
# 16         600 N Main St                             Alma    54610      US
# 17        112 N Shore Dr                    Fountain City    54629      US
# 18         407 S Mill St                         Rushford    55971      US
# 19         5242 W 6th St                           Winona    55987      US
# 20           65 E 4th St                           Winona    55987      US
# 21           619 Huff St                           Winona    55987      US
# 22          111 W 3rd St                           Winona    55987      US
# 23          1 N Shore Dr     None     None  Fountain City    54629      US
# 24       1441 Service Dr                           Winona    55987      US
# 25       1611 Service Dr                           Winona    55987      US
# 26     1429 W Service Dr                           Winona    55987      US
# 27  22852 County Road 17                           Winona    55987      US
#
#    state                                 display_address
# 0     WI             [214 N Main St, Cochrane, WI 54622]
# 1     WI             [115 4th St S, La Crosse, WI 54601]
# 2     WI               [327 Jay St, La Crosse, WI 54601]
# 3     WI    [205 S Holmen Dr, Ste 106, Holmen, WI 54636]
# 4     WI  [1311 La Crescent Pl, French Island, WI 54603]
# 5     MN          [236 E Main St, La Crescent, MN 55947]
# 6     WI        [19847 E Gale Ave, Galesville, WI 54630]
# 7     MN                 [78 E 4th St, Winona, MN 55987]
# 8     MN                [110 E Main St, Utica, MN 55979]
# 9     MN             [110 N Grant St, Houston, MN 55943]
# 10    WI           [23991 3rd St, Trempealeau, WI 54661]
# 11    WI        [N5610 County Rd Ot, Onalaska, WI 54650]
# 12    MN      [444 N Chestnut St, La Crescent, MN 55947]
# 13    MN                [77 Lafayette, Winona, MN 55987]
# 14    MN             [610 E Sarnia St, Winona, MN 55987]
# 15    WI            [1505 S Holmen Dr, Holmen, WI 54636]
# 16    WI                 [600 N Main St, Alma, WI 54610]
# 17    WI       [112 N Shore Dr, Fountain City, WI 54629]
# 18    MN             [407 S Mill St, Rushford, MN 55971]
# 19    MN               [5242 W 6th St, Winona, MN 55987]
# 20    MN                 [65 E 4th St, Winona, MN 55987]
# 21    MN                 [619 Huff St, Winona, MN 55987]
# 22    MN                [111 W 3rd St, Winona, MN 55987]
# 23    WI         [1 N Shore Dr, Fountain City, WI 54629]
# 24    MN             [1441 Service Dr, Winona, MN 55987]
# 25    MN             [1611 Service Dr, Winona, MN 55987]
# 26    MN           [1429 W Service Dr, Winona, MN 55987]
# 27    MN        [22852 County Road 17, Winona, MN 55987]

# %% [markdown]
# Next, the contents of the WinonaList_NormalizeLocation dataframe will need to be joined to WinonaList dataframe from above (that contains all the other columns).
#
# The inherent <strong>index</strong> will be as the *key* for this simple join.  The index for the WinonaList_NormalizeLocation dataframe goes from 0 to 17.  The index in the WinonaList dataframe will reset to go from 0 to 17.  The current index in the WinonaList is from before the filters being applied above.

# %%
WinonaList = WinonaList.reset_index(drop=True)

# %% [markdown]
# Check to make sure reindexing worked for the WinonaList dataframe.

# %%
WinonaList
# Out:
#                              name  \
# 0            NorthEnd Pub & Grill
# 1                   The Root Note
# 2   Pickerman's Soup & Sandwiches
# 3                   Taste of Thai
# 4        River Rats Bar and Grill
# 5                    Kaddy's Kafe
# 6                Garden of Eatin'
# 7                     Beno's Deli
# 8          Brewskie's Bar & Grill
# 9          Barista's Coffee House
# 10                     River Cafe
# 11                    Midway Deli
# 12      Schmitty's TimeOut Tavern
# 13              The Acoustic Cafe
# 14             Lakeview Drive Inn
# 15                   Pizza Corral
# 16                    Pier 4 Cafe
# 17             Golden Frog Saloon
# 18     Creamery Pizza & Ice Cream
# 19            Rocco's Pub & Pizza
# 20                  Bub's Brewing
# 21        Winona Sandwich Company
# 22         Great Hunan Restaurant
# 23         Wingdam Saloon & Grill
# 24                       Culver's
# 25       Winona Family Restaurant
# 26       Wellington's Pub & Grill
# 27        The Grill at Signatures
#
#                                             image_url review_count  rating  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/x5jzKR...           14     5.0
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/ahQdtU...           82     4.5
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/lfQw31...           64     4.5
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/IpG7kh...           42     4.5
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/FfTc_M...           35     4.5
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/cJXl6r...           28     4.5
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/rW68Cp...           24     4.5
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC...           22     4.5
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/llnczw...           21     4.5
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/P-MzJ7...           18     4.5
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/8m2yDp...           17     4.5
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/ueT-EP...           13     4.5
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/btkUYa...           10     4.5
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/bcDdRg...           77     4.0
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/uDUhkd...           45     4.0
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/ekGS6n...           27     4.0
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/w_h-vM...           26     4.0
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/IjH6sA...           25     4.0
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/4btuow...           14     4.0
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/pjaUxD...           12     4.0
# 20  https://s3-media1.fl.yelpcdn.com/bphoto/znNYZv...           66     3.5
# 21  https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgR...           39     3.5
# 22  https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK3...           28     3.5
# 23  https://s3-media1.fl.yelpcdn.com/bphoto/60SgiE...           15     3.5
# 24  https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1o...           12     3.5
# 25  https://s3-media4.fl.yelpcdn.com/bphoto/lxYd9Z...           32     3.0
# 26  https://s3-media3.fl.yelpcdn.com/bphoto/_Ep3L8...           20     3.0
# 27  https://s3-media4.fl.yelpcdn.com/bphoto/sBuQQs...           15     3.0
#
#                                              location
# 0   {'address1': '214 N Main St', 'address2': '', ...
# 1   {'address1': '115 4th St S', 'address2': '', '...
# 2   {'address1': '327 Jay St', 'address2': '', 'ad...
# 3   {'address1': '205 S Holmen Dr', 'address2': 'S...
# 4   {'address1': '1311 La Crescent Pl', 'address2'...
# 5   {'address1': '236 E Main St', 'address2': '', ...
# 6   {'address1': '19847 E Gale Ave', 'address2': '...
# 7   {'address1': '78 E 4th St', 'address2': '', 'a...
# 8   {'address1': '110 E Main St', 'address2': '', ...
# 9   {'address1': '110 N Grant St', 'address2': Non...
# 10  {'address1': '23991 3rd St', 'address2': None,...
# 11  {'address1': 'N5610 County Rd Ot', 'address2':...
# 12  {'address1': '444 N Chestnut St', 'address2': ...
# 13  {'address1': '77 Lafayette', 'address2': '', '...
# 14  {'address1': '610 E Sarnia St', 'address2': ''...
# 15  {'address1': '1505 S Holmen Dr', 'address2': '...
# 16  {'address1': '600 N Main St', 'address2': '', ...
# 17  {'address1': '112 N Shore Dr', 'address2': '',...
# 18  {'address1': '407 S Mill St', 'address2': '', ...
# 19  {'address1': '5242 W 6th St', 'address2': '', ...
# 20  {'address1': '65 E 4th St', 'address2': '', 'a...
# 21  {'address1': '619 Huff St', 'address2': '', 'a...
# 22  {'address1': '111 W 3rd St', 'address2': '', '...
# 23  {'address1': '1 N Shore Dr', 'address2': None,...
# 24  {'address1': '1441 Service Dr', 'address2': ''...
# 25  {'address1': '1611 Service Dr', 'address2': ''...
# 26  {'address1': '1429 W Service Dr', 'address2': ...
# 27  {'address1': '22852 County Road 17', 'address2...

# %% [markdown]
# Complete the simple join.

# %%
WinonaList_WithLocation = WinonaList.join(WinonaList_NormalizeLocation)

# %% [markdown]
# Taking a look at the dataframe after the JOIN.

# %%
WinonaList_WithLocation
# Out:
#                              name  \
# 0            NorthEnd Pub & Grill
# 1                   The Root Note
# 2   Pickerman's Soup & Sandwiches
# 3                   Taste of Thai
# 4        River Rats Bar and Grill
# 5                    Kaddy's Kafe
# 6                Garden of Eatin'
# 7                     Beno's Deli
# 8          Brewskie's Bar & Grill
# 9          Barista's Coffee House
# 10                     River Cafe
# 11                    Midway Deli
# 12      Schmitty's TimeOut Tavern
# 13              The Acoustic Cafe
# 14             Lakeview Drive Inn
# 15                   Pizza Corral
# 16                    Pier 4 Cafe
# 17             Golden Frog Saloon
# 18     Creamery Pizza & Ice Cream
# 19            Rocco's Pub & Pizza
# 20                  Bub's Brewing
# 21        Winona Sandwich Company
# 22         Great Hunan Restaurant
# 23         Wingdam Saloon & Grill
# 24                       Culver's
# 25       Winona Family Restaurant
# 26       Wellington's Pub & Grill
# 27        The Grill at Signatures
#
#                                             image_url review_count  rating  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/x5jzKR...           14     5.0
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/ahQdtU...           82     4.5
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/lfQw31...           64     4.5
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/IpG7kh...           42     4.5
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/FfTc_M...           35     4.5
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/cJXl6r...           28     4.5
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/rW68Cp...           24     4.5
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC...           22     4.5
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/llnczw...           21     4.5
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/P-MzJ7...           18     4.5
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/8m2yDp...           17     4.5
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/ueT-EP...           13     4.5
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/btkUYa...           10     4.5
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/bcDdRg...           77     4.0
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/uDUhkd...           45     4.0
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/ekGS6n...           27     4.0
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/w_h-vM...           26     4.0
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/IjH6sA...           25     4.0
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/4btuow...           14     4.0
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/pjaUxD...           12     4.0
# 20  https://s3-media1.fl.yelpcdn.com/bphoto/znNYZv...           66     3.5
# 21  https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgR...           39     3.5
# 22  https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK3...           28     3.5
# 23  https://s3-media1.fl.yelpcdn.com/bphoto/60SgiE...           15     3.5
# 24  https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1o...           12     3.5
# 25  https://s3-media4.fl.yelpcdn.com/bphoto/lxYd9Z...           32     3.0
# 26  https://s3-media3.fl.yelpcdn.com/bphoto/_Ep3L8...           20     3.0
# 27  https://s3-media4.fl.yelpcdn.com/bphoto/sBuQQs...           15     3.0
#
#                                              location              address1  \
# 0   {'address1': '214 N Main St', 'address2': '', ...         214 N Main St
# 1   {'address1': '115 4th St S', 'address2': '', '...          115 4th St S
# 2   {'address1': '327 Jay St', 'address2': '', 'ad...            327 Jay St
# 3   {'address1': '205 S Holmen Dr', 'address2': 'S...       205 S Holmen Dr
# 4   {'address1': '1311 La Crescent Pl', 'address2'...   1311 La Crescent Pl
# 5   {'address1': '236 E Main St', 'address2': '', ...         236 E Main St
# 6   {'address1': '19847 E Gale Ave', 'address2': '...      19847 E Gale Ave
# 7   {'address1': '78 E 4th St', 'address2': '', 'a...           78 E 4th St
# 8   {'address1': '110 E Main St', 'address2': '', ...         110 E Main St
# 9   {'address1': '110 N Grant St', 'address2': Non...        110 N Grant St
# 10  {'address1': '23991 3rd St', 'address2': None,...          23991 3rd St
# 11  {'address1': 'N5610 County Rd Ot', 'address2':...    N5610 County Rd Ot
# 12  {'address1': '444 N Chestnut St', 'address2': ...     444 N Chestnut St
# 13  {'address1': '77 Lafayette', 'address2': '', '...          77 Lafayette
# 14  {'address1': '610 E Sarnia St', 'address2': ''...       610 E Sarnia St
# 15  {'address1': '1505 S Holmen Dr', 'address2': '...      1505 S Holmen Dr
# 16  {'address1': '600 N Main St', 'address2': '', ...         600 N Main St
# 17  {'address1': '112 N Shore Dr', 'address2': '',...        112 N Shore Dr
# 18  {'address1': '407 S Mill St', 'address2': '', ...         407 S Mill St
# 19  {'address1': '5242 W 6th St', 'address2': '', ...         5242 W 6th St
# 20  {'address1': '65 E 4th St', 'address2': '', 'a...           65 E 4th St
# 21  {'address1': '619 Huff St', 'address2': '', 'a...           619 Huff St
# 22  {'address1': '111 W 3rd St', 'address2': '', '...          111 W 3rd St
# 23  {'address1': '1 N Shore Dr', 'address2': None,...          1 N Shore Dr
# 24  {'address1': '1441 Service Dr', 'address2': ''...       1441 Service Dr
# 25  {'address1': '1611 Service Dr', 'address2': ''...       1611 Service Dr
# 26  {'address1': '1429 W Service Dr', 'address2': ...     1429 W Service Dr
# 27  {'address1': '22852 County Road 17', 'address2...  22852 County Road 17
#
#    address2 address3           city zip_code country state  \
# 0                          Cochrane    54622      US    WI
# 1                         La Crosse    54601      US    WI
# 2                         La Crosse    54601      US    WI
# 3   Ste 106     None         Holmen    54636      US    WI
# 4      None           French Island    54603      US    WI
# 5               None    La Crescent    55947      US    MN
# 6                        Galesville    54630      US    WI
# 7                            Winona    55987      US    MN
# 8                             Utica    55979      US    MN
# 9      None     None        Houston    55943      US    MN
# 10     None             Trempealeau    54661      US    WI
# 11                         Onalaska    54650      US    WI
# 12                      La Crescent    55947      US    MN
# 13                           Winona    55987      US    MN
# 14                           Winona    55987      US    MN
# 15                           Holmen    54636      US    WI
# 16                             Alma    54610      US    WI
# 17                    Fountain City    54629      US    WI
# 18                         Rushford    55971      US    MN
# 19                           Winona    55987      US    MN
# 20                           Winona    55987      US    MN
# 21                           Winona    55987      US    MN
# 22                           Winona    55987      US    MN
# 23     None     None  Fountain City    54629      US    WI
# 24                           Winona    55987      US    MN
# 25                           Winona    55987      US    MN
# 26                           Winona    55987      US    MN
# 27                           Winona    55987      US    MN
#
#                                    display_address
# 0              [214 N Main St, Cochrane, WI 54622]
# 1              [115 4th St S, La Crosse, WI 54601]
# 2                [327 Jay St, La Crosse, WI 54601]
# 3     [205 S Holmen Dr, Ste 106, Holmen, WI 54636]
# 4   [1311 La Crescent Pl, French Island, WI 54603]
# 5           [236 E Main St, La Crescent, MN 55947]
# 6         [19847 E Gale Ave, Galesville, WI 54630]
# 7                  [78 E 4th St, Winona, MN 55987]
# 8                 [110 E Main St, Utica, MN 55979]
# 9              [110 N Grant St, Houston, MN 55943]
# 10           [23991 3rd St, Trempealeau, WI 54661]
# 11        [N5610 County Rd Ot, Onalaska, WI 54650]
# 12      [444 N Chestnut St, La Crescent, MN 55947]
# 13                [77 Lafayette, Winona, MN 55987]
# 14             [610 E Sarnia St, Winona, MN 55987]
# 15            [1505 S Holmen Dr, Holmen, WI 54636]
# 16                 [600 N Main St, Alma, WI 54610]
# 17       [112 N Shore Dr, Fountain City, WI 54629]
# 18             [407 S Mill St, Rushford, MN 55971]
# 19               [5242 W 6th St, Winona, MN 55987]
# 20                 [65 E 4th St, Winona, MN 55987]
# 21                 [619 Huff St, Winona, MN 55987]
# 22                [111 W 3rd St, Winona, MN 55987]
# 23         [1 N Shore Dr, Fountain City, WI 54629]
# 24             [1441 Service Dr, Winona, MN 55987]
# 25             [1611 Service Dr, Winona, MN 55987]
# 26           [1429 W Service Dr, Winona, MN 55987]
# 27        [22852 County Road 17, Winona, MN 55987]

# %% [markdown]
# Next, <strong>keep</strong> only restaurant locations in Winona.

# %%
WinonaList_WithLocation_OnlyWinona = (
                          WinonaList_WithLocation
                          >> filter_by(X.city == "Winona")
                          >> select(X.name, X.image_url, X.review_count, X.rating, X.display_address)
                       )

WinonaList_WithLocation_OnlyWinona = WinonaList_WithLocation_OnlyWinona.reset_index(drop=True)
WinonaList_WithLocation_OnlyWinona
# Out:
#                         name  \
# 0                Beno's Deli
# 1          The Acoustic Cafe
# 2         Lakeview Drive Inn
# 3        Rocco's Pub & Pizza
# 4              Bub's Brewing
# 5    Winona Sandwich Company
# 6     Great Hunan Restaurant
# 7                   Culver's
# 8   Winona Family Restaurant
# 9   Wellington's Pub & Grill
# 10   The Grill at Signatures
#
#                                             image_url review_count  rating  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC...           22     4.5
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/bcDdRg...           77     4.0
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/uDUhkd...           45     4.0
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/pjaUxD...           12     4.0
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/znNYZv...           66     3.5
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgR...           39     3.5
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK3...           28     3.5
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1o...           12     3.5
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/lxYd9Z...           32     3.0
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/_Ep3L8...           20     3.0
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/sBuQQs...           15     3.0
#
#                              display_address
# 0            [78 E 4th St, Winona, MN 55987]
# 1           [77 Lafayette, Winona, MN 55987]
# 2        [610 E Sarnia St, Winona, MN 55987]
# 3          [5242 W 6th St, Winona, MN 55987]
# 4            [65 E 4th St, Winona, MN 55987]
# 5            [619 Huff St, Winona, MN 55987]
# 6           [111 W 3rd St, Winona, MN 55987]
# 7        [1441 Service Dr, Winona, MN 55987]
# 8        [1611 Service Dr, Winona, MN 55987]
# 9      [1429 W Service Dr, Winona, MN 55987]
# 10  [22852 County Road 17, Winona, MN 55987]

# %% [markdown]
# Recall, the goal is to create an HTML file that contains a properly sorted list of restaurants in Winona.  A few modifications are needed in order to create an HTML file.  For example, an *image tag* and *link tag* will be created for the **image_url** field and the **display_address** field that will be used to connect to the Google Maps API.
#
# *  Image tag:  \<img src=https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC5xLgybMzV8NxGqyw/o.jpg width="100px" height="100px"\>
#
# *  Link tag: \<a href="https://www.google.com/maps/place/78+E+4th+St+Winona,+MN+55987" target="_blank">Map</a\>
#
#
# A new field, named **rank**, will be used to rank the restrauants from 1 on up.

# %%
WinonaList_WithLocation_OnlyWinona_PicMap = (
                          WinonaList_WithLocation_OnlyWinona
                          >> mutate(pic = 
                                          '<img src="' 
                                           + X.image_url 
                                           + '" width="100px" height="100px">'
                                    )
                          >> mutate(mapurl =
                                         '<a href="https://www.google.com/maps/place/'
                                          + X.display_address.str.join(sep=' ').str.replace(' ','+')
                                          + '" target="_blank">Map</a>'
                                    )
                          >> select(X.name, X.review_count, X.rating, X.pic, X.mapurl)

                       )
#Create a vector from 1 to n -- used for ranks
WinonaList_WithLocation_OnlyWinona_PicMap['rank'] = 1 + np.arange(len(WinonaList_WithLocation_OnlyWinona_PicMap))

#Move the selected column to left-most column
WinonaList_WithLocation_OnlyWinona_PicMap.insert(0,'rank',WinonaList_WithLocation_OnlyWinona_PicMap.pop('rank'))

print(WinonaList_WithLocation_OnlyWinona_PicMap.to_string(index=False))
# Out:
#  rank                     name review_count  rating                                                                                                           pic                                                                                                    mapurl
#     1              Beno's Deli           22     4.5 <img src="https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC5xLgybMzV8NxGqyw/o.jpg" width="100px" height="100px">          <a href="https://www.google.com/maps/place/78+E+4th+St+Winona,+MN+55987" target="_blank">Map</a>
#     2        The Acoustic Cafe           77     4.0 <img src="https://s3-media2.fl.yelpcdn.com/bphoto/bcDdRgDmRBrXjWyb3yK3eQ/o.jpg" width="100px" height="100px">         <a href="https://www.google.com/maps/place/77+Lafayette+Winona,+MN+55987" target="_blank">Map</a>
#     3       Lakeview Drive Inn           45     4.0 <img src="https://s3-media3.fl.yelpcdn.com/bphoto/uDUhkdZ74iu_Vr-pnCZe6Q/o.jpg" width="100px" height="100px">      <a href="https://www.google.com/maps/place/610+E+Sarnia+St+Winona,+MN+55987" target="_blank">Map</a>
#     4      Rocco's Pub & Pizza           12     4.0 <img src="https://s3-media1.fl.yelpcdn.com/bphoto/pjaUxDKFn4hxkNhCxwKwBA/o.jpg" width="100px" height="100px">        <a href="https://www.google.com/maps/place/5242+W+6th+St+Winona,+MN+55987" target="_blank">Map</a>
#     5            Bub's Brewing           66     3.5 <img src="https://s3-media1.fl.yelpcdn.com/bphoto/znNYZv_myu4yQvTZzTvwkg/o.jpg" width="100px" height="100px">          <a href="https://www.google.com/maps/place/65+E+4th+St+Winona,+MN+55987" target="_blank">Map</a>
#     6  Winona Sandwich Company           39     3.5 <img src="https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgRkiOW5ZomQ1e9WzQA/o.jpg" width="100px" height="100px">          <a href="https://www.google.com/maps/place/619+Huff+St+Winona,+MN+55987" target="_blank">Map</a>
#     7   Great Hunan Restaurant           28     3.5 <img src="https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK38viyWe-JWgbECckg/o.jpg" width="100px" height="100px">         <a href="https://www.google.com/maps/place/111+W+3rd+St+Winona,+MN+55987" target="_blank">Map</a>
#     8                 Culver's           12     3.5 <img src="https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1oPG-fkCF5QI4znL-A/o.jpg" width="100px" height="100px">      <a href="https://www.google.com/maps/place/1441+Service+Dr+Winona,+MN+55987" target="_blank">Map</a>
#     9 Winona Family Restaurant           32     3.0 <img src="https://s3-media4.fl.yelpcdn.com/bphoto/lxYd9Z-HtWlfRX9UqlUl-w/o.jpg" width="100px" height="100px">      <a href="https://www.google.com/maps/place/1611+Service+Dr+Winona,+MN+55987" target="_blank">Map</a>
#    10 Wellington's Pub & Grill           20     3.0 <img src="https://s3-media3.fl.yelpcdn.com/bphoto/_Ep3L84QrB37KGC_6eO7fw/o.jpg" width="100px" height="100px">    <a href="https://www.google.com/maps/place/1429+W+Service+Dr+Winona,+MN+55987" target="_blank">Map</a>
#    11  The Grill at Signatures           15     3.0 <img src="https://s3-media4.fl.yelpcdn.com/bphoto/sBuQQsov3ErlCKOc0xcN1A/o.jpg" width="100px" height="100px"> <a href="https://www.google.com/maps/place/22852+County+Road+17+Winona,+MN+55987" target="_blank">Map</a>

# %% [markdown]
# ## Creating the HTML File

# %% [markdown]
# To start, this dataframe will be converted into an HTML table using the to_html() method.

# %%
WinonaList_WithLocation_OnlyWinona_PicMap.to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>rank</th>\n      <th>name</th>\n      <th>review_count</th>\n      <th>rating</th>\n      <th>pic</th>\n      <th>mapurl</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>1</td>\n      <td>Beno\'s Deli</td>\n      <td>22</td>\n      <td>4.5</td>\n      <td>&lt;img src="https://s3-media1.fl.yelpcdn.com/bphoto/snAzXC5xLgybMzV8NxGqyw/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/78+E+4th+St+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>2</td>\n      <td>The Acoustic Cafe</td>\n      <td>77</td>\n      <td>4.0</td>\n      <td>&lt;img src="https://s3-media2.fl.yelpcdn.com/bphoto/bcDdRgDmRBrXjWyb3yK3eQ/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/77+Lafayette+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>3</td>\n      <td>Lakeview Drive Inn</td>\n      <td>45</td>\n      <td>4.0</td>\n      <td>&lt;img src="https://s3-media3.fl.yelpcdn.com/bphoto/uDUhkdZ74iu_Vr-pnCZe6Q/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/610+E+Sarnia+St+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>4</td>\n      <td>Rocco\'s Pub &amp; Pizza</td>\n      <td>12</td>\n      <td>4.0</td>\n      <td>&lt;img src="https://s3-media1.fl.yelpcdn.com/bphoto/pjaUxDKFn4hxkNhCxwKwBA/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/5242+W+6th+St+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>5</td>\n      <td>Bub\'s Brewing</td>\n      <td>66</td>\n      <td>3.5</td>\n      <td>&lt;img src="https://s3-media1.fl.yelpcdn.com/bphoto/znNYZv_myu4yQvTZzTvwkg/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/65+E+4th+St+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>6</td>\n      <td>Winona Sandwich Company</td>\n      <td>39</td>\n      <td>3.5</td>\n      <td>&lt;img src="https://s3-media4.fl.yelpcdn.com/bphoto/ntWfgRkiOW5ZomQ1e9WzQA/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/619+Huff+St+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>7</td>\n      <td>Great Hunan Restaurant</td>\n      <td>28</td>\n      <td>3.5</td>\n      <td>&lt;img src="https://s3-media3.fl.yelpcdn.com/bphoto/q-CzK38viyWe-JWgbECckg/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/111+W+3rd+St+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>8</td>\n      <td>Culver\'s</td>\n      <td>12</td>\n      <td>3.5</td>\n      <td>&lt;img src="https://s3-media2.fl.yelpcdn.com/bphoto/bcGL1oPG-fkCF5QI4znL-A/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/1441+Service+Dr+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>9</td>\n      <td>Winona Family Restaurant</td>\n      <td>32</td>\n      <td>3.0</td>\n      <td>&lt;img src="https://s3-media4.fl.yelpcdn.com/bphoto/lxYd9Z-HtWlfRX9UqlUl-w/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/1611+Service+Dr+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr>\n      <td>10</td>\n      <td>Wellington\'s Pub &amp; Grill</td>\n      <td>20</td>\n      <td>3.0</td>\n      <td>&lt;img src="https://s3-media3.fl.yelpcdn.com/bphoto/_Ep3L84QrB37KGC_6eO7fw/o.jpg" width="100px" height="100px"&gt;</td>\n      <td>&lt;a href="https://www.google.com/maps/place/1429+W+Service+Dr+Winona,+MN+55987" target="_blank"&gt;Map&lt;/a&gt;</td>\n    </tr>\n    <tr ...

# %% [markdown]
# Instead of pushing the HTML converted table to the screen, let's push this contents into a HTML file.  The name of the html file is **WinonaYelpList.html**.  This file is being written to the sample_data/ directory.

# %%
text_file = open("sample_data/WinonaYelpList.html", "w")
text_file.write(WinonaList_WithLocation_OnlyWinona_PicMap.to_html(index=False))
text_file.close()

# %% [markdown]
# The data.frame to html table conversion done above created the contents of the html file; however, other tags are needed for the HTML file.  For example, the \<html\> & \</html\> and \<body\> & \</body\> tags are a required part of an html file.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=12RH4q90vusTh8Oaf_jWe70fBulOgVN9E" width='50%' height='50%'></p>

# %% [markdown]
# Adding <strong>\<html\><strong> to beginning of file.

# %%
# !sed -i '1i \<html>\' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Next, adding <strong>\<body\></strong> on the 2nd line.

# %%
# !sed -i '2i \<body>\' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Next, need to put \<\body\> and \<\html\> tags at end of HTML file.

# %%
# !sed -i '$ a </body>' /content/sample_data/WinonaYelpList.html
# !sed -i '$ a </html>' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# The HTML conversion done by Pandas does have some minor issues that will need to be cleaned up.
#
#
# *   The < symbol was written as \&lt;
# *   The > symbol was written as \&gt;

# %% [markdown]
# Fixing the beginning of each image and link tag.

# %%
# !sed -i 's/&lt;/</g' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Similarly, fix the end tags...

# %%
# !sed -i 's/&gt;/>/g' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Next, center the contents of the header row using the text-align arugment.

# %%
# !sed -i 's/text-align: right;/text-align: center;/' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Making the table headers slighly larger and removing pic and mapurl names all together.

# %%
# !sed -i 's/rank/<font size="+1"\>Rank<\/font>/' /content/sample_data/WinonaYelpList.html
# !sed -i 's/name/<font size="+1"\>Restaurant<br>Name<\/font>/' /content/sample_data/WinonaYelpList.html
# !sed -i 's/review_count/<font size="+1"\># of <br>Reviews<\/font>/' /content/sample_data/WinonaYelpList.html
# !sed -i 's/rating/<font size="+1"\>Rating<\/font>/' /content/sample_data/WinonaYelpList.html
# !sed -i 's/pic/<font size="+1"\>\&nbsp;<\/font>/' /content/sample_data/WinonaYelpList.html
# !sed -i 's/mapurl/<font size="+1"\>\&nbsp;<\/font>/' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Next, specify that the contents of the table be centered...

# %%
# !sed -i 's/<tbody>/<tbody style="text-align: center;">/' /content/sample_data/WinonaYelpList.html

# %% [markdown]
# Taking a look at a final version of this file...

# %%
# !cat /content/sample_data/WinonaYelpList.html

# %% [markdown]
# ## The Final Product

# %% [markdown]
# The following is a picture of the final HTML file.  This has the restaurants truely sorted by Rating.  Filters were applied in gettnig this table; thus, not all locations in Winona are included.

# %% [markdown]
# <p align='center'><img src="https://drive.google.com/uc?export=view&id=1uc5709XLHynutOCqFW1r80JwbmYDMVZd" width='50%' height='50%'></p>

# %% [markdown]
# ---
#
#
#
# ---
# End of Document
